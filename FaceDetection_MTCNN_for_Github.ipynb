# %% [markdown]
# <a href="https://colab.research.google.com/github/nimanejatifar/AI_Overfitting_Underfitting/blob/main/FaceDetection_MTCNN_for_Github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mtcnn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 23.4 MB/s eta 0:00:00
# ...

# %%
# !mkdir images
# Out:
# mkdir: cannot create directory ‘images’: File exists

# %%
import mtcnn

# %%
from mtcnn.mtcnn import MTCNN
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# load image from file:
pixels = plt.imread('./images/test3.jpg')

# %%
detector = MTCNN()
results = detector.detect_faces(pixels)
# Out:
# ...
# 1/1 [==============================] - 0s 275ms/step

# %%
results
# MTCNN --> Multi Task CNN
# result is a list of dictionaries:
# box : x, y, width, height
# confidence: binary classification
# keypoints : landmarks
# Out:
# [{'box': [447, 236, 73, 89],
#   'confidence': 0.9999808073043823,
#   'keypoints': {'left_eye': (468, 264),
#    'right_eye': (502, 264),
#    'nose': (485, 279),
#    'mouth_left': (470, 301),
#    'mouth_right': (498, 302)}},
#  {'box': [680, 245, 79, 101],
#   'confidence': 0.9999709129333496,
#   'keypoints': {'left_eye': (699, 284),
#    'right_eye': (737, 283),
#    'nose': (717, 305),
#    'mouth_left': (704, 325),
#    'mouth_right': (733, 324)}},
#  {'box': [231, 124, 81, 105],
#   'confidence': 0.9995217323303223,
#   'keypoints': {'left_eye': (266, 156),
#    'right_eye': (299, 174),
#    'nose': (279, 178),
#    'mouth_left': (251, 192),
#    'mouth_right': (279, 208)}},
#  {'box': [948, 197, 89, 109],
#   'confidence': 0.9994858503341675,
#   'keypoints': {'left_eye': (970, 238),
#    'right_eye': (1012, 234),
#    'nose': (990, 251),
#    'mouth_left': (976, 280),
#    'mouth_right': (1010, 277)}}]

# %%
def draw_facebox(filename, result_list):
    data = plt.imread(filename)
    plt.imshow(data)
    ax = plt.gca()

    for result in result_list:
        x, y, width, height = result['box'] # coordinates
        rect = plt.Rectangle((x, y), width, height, fill=False, color='yellow') # create the shape
        ax.add_patch(rect)

    plt.show()

# %%
draw_facebox('./images/test3.jpg', results)

# %%
def draw_facebox_and_keypoints(filename, result_list):
    data = plt.imread(filename)
    plt.imshow(data)
    ax = plt.gca()

    for result in result_list:

        x, y, width, height = result['box']
        rect = plt.Rectangle((x, y), width, height,fill=False, color='yellow')
        ax.add_patch(rect)

        for key, value in result['keypoints'].items(): # draw the dots
            dot = plt.Circle(value, radius=1.8, color='red')
            ax.add_patch(dot)

    plt.show()

# %%
draw_facebox_and_keypoints('./images/test3.jpg', results)
